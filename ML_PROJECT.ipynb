# %% [markdown]
# <a href="https://colab.research.google.com/github/Someone18-6/ml-house-price-pred/blob/main/ML_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/House_Price_india.csv")

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
X = data[['area', 'bedrooms', 'bathrooms']]
y = data['Price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3363/878312050.py in <cell line: 0>()
# ----> 1 X = data[['area', 'bedrooms', 'bathrooms']]
#       2 y = data['Price']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
X = data[['living area', 'number of bedrooms', 'number of bathrooms']]
y = data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
error = mean_squared_error(y_test,predictions)
print("Error: ",error)
# Out:
# Error:  59231141840.13323

# %%
new_house = [[2000,3,2]]
price = model.predict(new_house)
print("Predicted Price: ",price)
# Out:
# Predicted Price:  [528411.56758141]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_house = pd.DataFrame([[2000, 3, 2]],
                         columns=['living area', 'number of bedrooms', 'number of bathrooms'])

price = model.predict(new_house)
print("Predicted Price:", price)
# Out:
# Predicted Price: [528411.56758141]

# %%
new_house = pd.DataFrame([[2000, 3, 2]],
                         columns=['area', 'bedrooms', 'bathrooms'])

price = model.predict(new_house)
print("Predicted Price:", price)

# %%
new_house = pd.DataFrame([[2000, 3, 2]],
                         columns=['area', 'bedrooms', 'bathrooms'])

# %%
print("Predicted Price: ",price)
# Out:
# Predicted Price:  [528411.56758141]

# %%
new_house = pd.DataFrame([[2000, 3, 2]],
    columns=['living area', 'number of bedrooms', 'number of bathrooms'])

price = model.predict(new_house)
print("Predicted Price:", price)
# Out:
# Predicted Price: [528411.56758141]

# %%
price_inr = price[0] * 83

print("Predicted Price: ₹{:.2f}".format(price_inr))
# Out:
# Predicted Price: ₹43858160.11

# %%
price_inr = price[0] * 83

print("Predicted Price: ₹{:.2f}".format(price_inr))
# Out:
# Predicted Price: ₹65588831.18

# %%
price_inr = price[0] * 83

print("Predicted Price: ₹{:,.2f}".format(price_inr))
# Out:
# Predicted Price: ₹65,588,831.18

# %%
new_house = pd.DataFrame([[3000, 4, 3]],
    columns=['living area', 'number of bedrooms', 'number of bathrooms'])

price = model.predict(new_house)
price_inr = price[0] * 83
price_crore = price_inr / 10000000

print("Predicted Price: ₹{:.2f} Crore".format(price_crore))
# Out:
# Predicted Price: ₹6.56 Crore

# %%
new_house = pd.DataFrame([[3000, 4, 3]],
    columns=['living area', 'number of bedrooms', 'number of bathrooms'])

price = model.predict(new_house)

price_inr = price[0] * 83

crore = int(price_inr // 10000000)
lakh = (price_inr % 10000000) / 100000

print(f"Predicted Price: ₹{crore} Crore {lakh:.2f} Lakh")
# Out:
# Predicted Price: ₹6 Crore 55.89 Lakh

# %%
new_house = pd.DataFrame([[300, 1, 1]],
    columns=['living area', 'number of bedrooms', 'number of bathrooms'])

price = model.predict(new_house)

price_inr = price[0] * 83

crore = int(price_inr // 10000000)
lakh = (price_inr % 10000000) / 100000

print(f"Predicted Price: ₹{crore} Crore {lakh:.2f} Lakh")
# Out:
# Predicted Price: ₹0 Crore 85.97 Lakh

# %%
from sklearn.metrics import r2_score

score = r2_score(y_test, predictions)
print("R2 Score:", score)
# Out:
# R2 Score: 0.5260257469319101

# %%
X = data[['living area', 'number of bedrooms', 'number of bathrooms',
          'grade of the house', 'condition of the house',
          'number of floors', 'waterfront present',
          'number of views']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3363/3375088109.py in <cell line: 0>()
# ----> 1 X = data[['living area', 'number of bedrooms', 'number of bathrooms',
#       2           'grade of the house', 'condition of the house',
#       3           'number of floors', 'waterfront present',
#       4           'number of views']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
X = data[['area', 'bedrooms', 'bathrooms',
          'grade of the house', 'condition of the house',
          'number of floors', 'waterfront present',
          'number of views']]

# %%
new_house = pd.DataFrame([[3000, 4, 3, 8, 4, 2, 0, 3]],
    columns=['area', 'bedrooms', 'bathrooms',
             'grade of the house', 'condition of the house',
             'number of floors', 'waterfront present',
             'number of views'])

# %%
data = data.rename(columns={
    'living area': 'area',
    'number of bedrooms': 'bedrooms',
    'number of bathrooms': 'bathrooms',
    'Price': 'price'
})

# %%
X = data[['area', 'bedrooms', 'bathrooms',
          'grade of the house', 'condition of the house',
          'number of floors', 'waterfront present',
          'number of views']]

y = data['price']

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
new_house = pd.DataFrame([[3000, 4, 3, 8, 4, 2, 0, 3]],
    columns=['area', 'bedrooms', 'bathrooms',
             'grade of the house', 'condition of the house',
             'number of floors', 'waterfront present',
             'number of views'])

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
new_house = pd.DataFrame([[3000, 4, 3, 8, 4, 2, 0, 3]],
    columns=['area', 'bedrooms', 'bathrooms',
             'grade of the house', 'condition of the house',
             'number of floors', 'waterfront present',
             'number of views'])

# %%
from sklearn.metrics import r2_score

predictions = model.predict(X_test)
print("R2 Score:", r2_score(y_test, predictions))
# Out:
# R2 Score: 0.48857179704946174

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=200,
    max_depth=10,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=200, random_state=42)

# %%
X = data[['area', 'bedrooms', 'bathrooms',
          'grade of the house']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)
print("LR Score:", r2_score(y_test, lr.predict(X_test)))

# Random Forest
rf = RandomForestRegressor(n_estimators=200, max_depth=10)
rf.fit(X_train, y_train)
print("RF Score:", r2_score(y_test, rf.predict(X_test)))
# Out:
# LR Score: 0.5260257469319101
# RF Score: 0.5650697028076759

# %%
X = data[['area', 'bedrooms', 'bathrooms',
          'grade of the house',
          'Lattitude', 'Longitude']]

# %%
model = RandomForestRegressor(n_estimators=300, max_depth=12, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)
print("LR Score:", r2_score(y_test, lr.predict(X_test)))

# Random Forest
rf = RandomForestRegressor(n_estimators=200, max_depth=10)
rf.fit(X_train, y_train)
print("RF Score:", r2_score(y_test, rf.predict(X_test)))
# Out:
# LR Score: 0.5260257469319101
# RF Score: 0.5664865186823329
